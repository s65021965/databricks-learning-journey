# %% [markdown]
# Attended a voice session focused on Apache Spark fundamentals.
#
# Key takeaways:
# - Why Spark is faster than traditional batch systems like Hadoop
# - Concept of distributed computing and in-memory processing
# - Role of Spark in Databricks ecosystem
# - How Spark supports SQL, DataFrames, and ML workloads
#
# This session helped strengthen conceptual understanding before hands-on practice.
