# %% [markdown]
# Day 1 – Platform Setup & First Steps
# Practicing basic Spark-style DataFrame operations.

# %%
import pandas as pd

# Create simple DataFrame
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df = pd.DataFrame(data, columns=["product", "price"])
print(df)

# Filter expensive products
print(df[df["price"] > 1000])
# Out:
#    product  price
# 0   iPhone    999
# 1  Samsung    799
# 2  MacBook   1299
#    product  price
# 2  MacBook   1299
